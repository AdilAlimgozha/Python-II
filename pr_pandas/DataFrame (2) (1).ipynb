# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.DataFrame(np.random.randn(8, 4), columns=['A', 'B', 'C', 'D'])

# %%
df
# Out:
#           A         B         C         D
# 0  0.990004  0.968112 -0.211161 -0.692164
# 1  0.590521 -1.372270 -1.075985 -0.727052
# 2  0.737437 -0.575547 -1.341229 -0.657591
# 3  0.080816 -1.151766 -0.702479  0.065291
# 4 -0.225768 -0.669401  0.661405  1.175485
# 5  1.325875  0.470391  0.475647 -0.452538
# 6  0.751963  1.413400 -1.223358 -1.056092
# 7 -0.408843 -0.367496 -0.044224 -0.674298

# %%
df['A']
# Out:
# 0    0.990004
# 1    0.590521
# 2    0.737437
# 3    0.080816
# 4   -0.225768
# 5    1.325875
# 6    0.751963
# 7   -0.408843
# Name: A, dtype: float64

# %%
df.T
# Out:
#           0         1         2         3         4         5         6  \
# A  0.990004  0.590521  0.737437  0.080816 -0.225768  1.325875  0.751963
# B  0.968112 -1.372270 -0.575547 -1.151766 -0.669401  0.470391  1.413400
# C -0.211161 -1.075985 -1.341229 -0.702479  0.661405  0.475647 -1.223358
# D -0.692164 -0.727052 -0.657591  0.065291  1.175485 -0.452538 -1.056092
#
#           7
# A -0.408843
# B -0.367496
# C -0.044224
# D -0.674298

# %%
df[0:3]
# Out:
#           A         B         C         D
# 0  0.990004  0.968112 -0.211161 -0.692164
# 1  0.590521 -1.372270 -1.075985 -0.727052
# 2  0.737437 -0.575547 -1.341229 -0.657591

# %%
df.loc[:2,['A','C']]
# Out:
#           A         C
# 0  0.990004 -0.211161
# 1  0.590521 -1.075985
# 2  0.737437 -1.341229

# %%
df.iloc[3] #all columns with third element
# Out:
# A    0.080816
# B   -1.151766
# C   -0.702479
# D    0.065291
# Name: 3, dtype: float64

# %%
df.iloc[:,1:4:2]
# Out:
#           B         D
# 0  0.968112 -0.692164
# 1 -1.372270 -0.727052
# 2 -0.575547 -0.657591
# 3 -1.151766  0.065291
# 4 -0.669401  1.175485
# 5  0.470391 -0.452538
# 6  1.413400 -1.056092
# 7 -0.367496 -0.674298

# %%
df
# Out:
#           A         B         C         D
# 0  0.990004  0.968112 -0.211161 -0.692164
# 1  0.590521 -1.372270 -1.075985 -0.727052
# 2  0.737437 -0.575547 -1.341229 -0.657591
# 3  0.080816 -1.151766 -0.702479  0.065291
# 4 -0.225768 -0.669401  0.661405  1.175485
# 5  1.325875  0.470391  0.475647 -0.452538
# 6  0.751963  1.413400 -1.223358 -1.056092
# 7 -0.408843 -0.367496 -0.044224 -0.674298

# %%
df['E'] = np.arange(8)

# %%
df
# Out:
#           A         B         C         D  E
# 0  0.990004  0.968112 -0.211161 -0.692164  0
# 1  0.590521 -1.372270 -1.075985 -0.727052  1
# 2  0.737437 -0.575547 -1.341229 -0.657591  2
# 3  0.080816 -1.151766 -0.702479  0.065291  3
# 4 -0.225768 -0.669401  0.661405  1.175485  4
# 5  1.325875  0.470391  0.475647 -0.452538  5
# 6  0.751963  1.413400 -1.223358 -1.056092  6
# 7 -0.408843 -0.367496 -0.044224 -0.674298  7

# %%
# Out:
#                   B         C         D  E
# A
# -0.408843 -0.367496 -0.044224 -0.674298  7
# -0.225768 -0.669401  0.661405  1.175485  4
#  0.080816 -1.151766 -0.702479  0.065291  3
#  0.590521 -1.372270 -1.075985 -0.727052  1
#  0.737437 -0.575547 -1.341229 -0.657591  2
#  0.751963  1.413400 -1.223358 -1.056092  6
#  0.990004  0.968112 -0.211161 -0.692164  0
#  1.325875  0.470391  0.475647 -0.452538  5

# %%
plt.figure()
df.plot()
